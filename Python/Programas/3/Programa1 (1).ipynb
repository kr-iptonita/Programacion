# %% [markdown]
# Importación de Librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Ejercicio 1
# Haga una gráfica de las siguientes funciones:

# %%
def graficar_funcion(fx, rango_x):
    # Evaluación de la función en el rango dado
    x = np.linspace(rango_x[0], rango_x[1], 1000)
    y = eval(fx)  # Evalúa la cadena de texto como una expresión matemática

    # Configuración de la gráfica
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title('Gráfica de f(x) = ' + fx)

    # Mostrar la gráfica
    plt.show()

# %%
def graficar_funcion_3D(funcion, variable_x, variable_y, rango_x, rango_y):
    # Crear una malla de puntos en el rango especificado
    x = np.linspace(rango_x[0], rango_x[1], 100)
    y = np.linspace(rango_y[0], rango_y[1], 100)
    X, Y = np.meshgrid(x, y)

    # Evaluar la función en cada punto de la malla
    Z = eval(funcion)

    # Crear la figura y los ejes 3D
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Graficar la superficie 3D
    ax.plot_surface(X, Y, Z, cmap='viridis')

    # Etiquetar los ejes
    ax.set_xlabel(variable_x)
    ax.set_ylabel(variable_y)
    ax.set_zlabel('f({},{})'.format(variable_x, variable_y))

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# $f(x)=e^{2 \sin(0.4x)}5 \cos(4x)$
#
# $-20 \leq x \leq 20$

# %%
# Obtener la función y el rango del usuario
fx = 'np.exp(2*np.sin(0.4*x))*5*np.cos(4*x)'
print(fx)
x_min = -20.0
x_max = 20.0
rango_x = (x_min, x_max)

# Graficar la función
graficar_funcion(fx, rango_x)
# Out:
# np.exp(2*np.sin(0.4*x))*5*np.cos(4*x)

# %% [markdown]
# $f(x)=\frac{x^2+3x-5}{x^2-3x-10}$
#
# $-4 \leq x \leq 9$

# %%
# Obtener la función y el rango del usuario
fx = '(x**2+3*x-5)/(x**2-3*x-10)'
print(fx)
x_min = -4.0
x_max = 9.0
rango_x = (x_min, x_max)

# Graficar la función
graficar_funcion(fx, rango_x)
# Out:
# (x**2+3*x-5)/(x**2-3*x-10)

# %% [markdown]
# $x=r\cos(t), y=r\sin(t), z=\frac{ht}{2\pi n}$
#
# con
#
# $r=\frac{ab}{\sqrt{(b \cos(t))^2+(a \sin(t))^2}}e^{-0.04 t}, a=20, b=10, h=18, n=5$
#
# para $0 \leq t \leq 2\pi n$

# %%
# Parámetros
a = 20
b = 10
h = 18
n = 5

# Definir el rango de t
t = np.linspace(0, 2 * np.pi * n, 100)

# Calcular las coordenadas x, y, z
r = (a * b) / np.sqrt((b * np.cos(t))**2 + (a * np.sin(t))**2) * np.exp(-0.04 * t)
x = r * np.cos(t)
y = r * np.sin(t)
z = (h * t) / (2 * np.pi * n)

# Crear una figura y un objeto de subparcela 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la función en 3D
ax.plot(x, y, z, 'b')

# Configurar etiquetas y título
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Gráfico 3D de x, y, z')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# $f(x,y)=\cos(xy)cos(\sqrt{x^2+y^2})$
# con el dominio:
# $-\pi \leq x , y \leq \pi$

# %%
# Definir el rango
x = np.linspace(-np.pi, np.pi, 100)
y = np.linspace(-np.pi, np.pi, 100)

# Crear una malla de coordenadas
X, Y = np.meshgrid(x, y)

# Calcular los valores de la función en cada punto
Z = np.cos(X * Y) * np.cos(np.sqrt(X**2 + Y**2))

# Crear una figura y un objeto de subparcela 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la función en 3D
ax.plot_surface(X, Y, Z, cmap='viridis')

# Configurar etiquetas y título
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.set_title('Gráfico 3D de f(x, y) = cos(x*y) * cos(sqrt(x^2 + y^2))')

# Mostrar la gráfica
plt.show()
